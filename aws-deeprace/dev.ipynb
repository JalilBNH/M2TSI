# %%
import math
from matplotlib import pyplot as plt
import numpy as np

# %%
distance_from_center = np.arange(0, 0.6, 0.1)
track_width = 0.5
distance_reward = 1- (distance_from_center/track_width*0.5)**0.4

# %%
plt.plot(distance_from_center, distance_reward)

# %%
speed
